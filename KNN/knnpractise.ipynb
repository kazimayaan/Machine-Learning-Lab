# %% [markdown]
# <a href="https://colab.research.google.com/github/kazimayaan/Machine-Learning-Lab/blob/main/knnpractise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import csv
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
def KNN(data):
  print('enter the Weight,Height and ches size')
  a,b,c = input().split()
  a = int(a)
  b = int(b)
  c = int(c)
  for line in data:
    x = int(line[0])
    y = int(line[1])
    z = int(line[2])
    dist=np.sqrt((x-a)**2+(y-b)**2+(z-c)**2)
    line.append(dist)
  data.sort(key= lambda i:i[4])
  display(data)
  print()
  print('please enter the value of k')
  k = int(input())
  sc=0
  mc=0
  lc=0
  xlc=0
  for i in range(k):
    if data[i][3]=='S':
      sc+=1
    elif data[i][3]=='M':
      mc+=1
    elif data[i][3]=='L':
      lc+=1
    else:
      xlc+=1

  lol = [sc,mc,lc,xlc]
  ylan =['Small','Medium','Large','Xlarge']
  plt.bar(ylan,lol)
  plt.xlabel('size')
  plt.ylabel('nearest neighbours')
  plt.show()

  #  if sc>mc and sc>lc and sc> xlc:
  #    print("-----------Buy Small Size------------")
  #  elif mc>sc and mc>lc and mc> xlc:
  #    print("-----------Buy Medium Size------------")
  #  elif lc>mc and lc>sc and lc> xlc:
  #    print("-----------Buy Large Size------------")
  #  else:
  #    print("-----------Buy XL size-------------------")

# %%
def main():
  file = "/content/T-shirt1.csv"
  temp = pd.read_csv(file)
  display(temp)
  fd = csv.reader(open(file))
  data=[]
  for line in fd:
    data.append(line)
  DATA= data[1:]
  KNN(DATA)

# %%
main()
# Out:
#     Weight  height  chestsize T-shirt size
# 0       55     170         45            S
# 1       67     172         49            M
# 2       70     169         47            M
# 3       80     174         49            L
# 4       88     175         50           XL
# 5       67     171         44            M
# 6       50     166         40            S
# 7       90     178         52           XL
# 8       98     175         50           XL
# 9       60     160         42            S
# 10      75     175         48            L
# 11      78     174         50            L
# 12      66     168         46            M
# 13      79     171         49            L
# 14      44     160         44            S
# 15      99     179         56           XL
# enter the Weight,Height and ches size
# 60 160 48
# [['60', '160', '42', 'S', 6.0],
#  ['66', '168', '46', 'M', 10.198039027185569],
#  ['55', '170', '45', 'S', 11.575836902790225],
#  ['70', '169', '47', 'M', 13.490737563232042],
# ...
