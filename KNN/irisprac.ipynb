# %% [markdown]
# <a href="https://colab.research.google.com/github/kazimayaan/Machine-Learning-Lab/blob/main/irisprac.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import csv
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
def knn(data):
  print("please enter sepal length sepal width,petal length, petal width")
  a,b,c,d = input().split()
  print(a,b,c,d)
  a = float(a)
  b = float(b)
  c = float(c)
  d = float(d)

  for line in data:
    x = float(line[0])
    y = float(line[1])
    z = float(line[2])
    w = float(line[3])
    dist = np.sqrt((x-a)**2 + (y-b)**2 + (z-c)**2 + (w-d)**2)
    # dist= np.sqrt((x-a)**2+(y-b)**2+(z-c)**2+(w-d)**2)
    line.append(dist)

  data.sort(key = lambda i:i[5])
  display(data)
  
  print("please enter the value of k")

  k = input()
  k = int(k)
  ser = 0;
  ver = 0
  vir = 0
  # values = []
  
  # for val in range(k):

  for j in range(k):
    if data[j][4]=='Iris-setosa':
      ser+=1
    elif data[j][4]=='Iris-versicolor':
      ver+=1
    else:
      vir+=1

  print()
  print()
  print()
  pex = [vir,ver,ser]
  label = ['virginica', 'versicolor', 'sertosa']
  plt.bar(label,pex)
  plt.show()
    
  # display(values)

  
  
  if(ser>ver and ser>vir):
    print("the given flower is sertosa")
  elif(ver>ser and ver>vir):
    print("the given flower is vertosa")
  else:
    print("the given flower is virginica")

# %%
from pandas.core.internals.blocks import F
def main():
  file = "/content/iris.csv"
  temp = pd.read_csv(file)
  display(temp)
  fd = csv.reader(open(file))
  DATA=[]
  for line in fd:
    DATA.append(line)
  display(DATA)
  print()
  data=DATA[1:]
  knn(data)

# %%
main()
# Out:
#      slength  swidth  plength  pwidth        catogary
# 0        5.1     3.5      1.4     0.2     Iris-setosa
# 1        4.9     3.0      1.4     0.2     Iris-setosa
# 2        4.7     3.2      1.3     0.2     Iris-setosa
# 3        4.6     3.1      1.5     0.2     Iris-setosa
# 4        5.0     3.6      1.4     0.2     Iris-setosa
# ..       ...     ...      ...     ...             ...
# 145      6.7     3.0      5.2     2.3  Iris-virginica
# 146      6.3     2.5      5.0     1.9  Iris-virginica
# 147      6.5     3.0      5.2     2.0  Iris-virginica
# 148      6.2     3.4      5.4     2.3  Iris-virginica
# 149      5.9     3.0      5.1     1.8  Iris-virginica
#
# [150 rows x 5 columns]
# [['slength', 'swidth', 'plength', 'pwidth', 'catogary'],
#  ['5.1', '3.5', '1.4', '0.2', 'Iris-setosa'],
#  ['4.9', '3', '1.4', '0.2', 'Iris-setosa'],
#  ['4.7', '3.2', '1.3', '0.2', 'Iris-setosa'],
#  ['4.6', '3.1', '1.5', '0.2', 'Iris-setosa'],
#  ['5', '3.6', '1.4', '0.2', 'Iris-setosa'],
# ...
