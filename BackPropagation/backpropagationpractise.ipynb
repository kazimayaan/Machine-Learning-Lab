# %% [markdown]
# <a href="https://colab.research.google.com/github/kazimayaan/Machine-Learning-Lab/blob/main/backpropagationpractise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
ipn = 2
opn = 2
hln = 4
iteration = 6000

input = np.random.randint(1,5,ipn)
output= np.array([1.0,0.0])
hiddenlayer = np.random.rand(1,hln)

hidden_bias = np.random.rand(1,hln)
output_bias = np.random.rand(1,opn)

hidden_weight = np.random.rand(ipn,hln)
output_weight = np.random.rand(hln,opn)

def sigmoid(layer):
  return 1/(1+np.exp(-layer))
def gradient(layer):
  return layer*(1-layer)

for i in range(iteration):

  hiddenlayer = np.dot(input,hidden_weight)
  hiddenlayer = sigmoid(hiddenlayer+hidden_bias)

  outputlayer = np.dot(hiddenlayer,output_weight)
  outputlayer = sigmoid(outputlayer+output_bias)

  error = output - outputlayer
  gop = gradient(outputlayer)
  error_op = gop*error
  error_hiddenterm = gradient(hiddenlayer)*np.dot(error_op,output_weight.T)

  gradienthidden = np.dot(input.reshape(ipn,1),error_hiddenterm.reshape(1,hln))
  gradientop = np.dot(hiddenlayer.reshape(hln,1),error_op.reshape(1,opn))

  hidden_weight = hidden_weight + 0.5 * gradienthidden
  output_weight = output_weight + 0.5 * gradientop

  if i < 50 or i> iteration-50:
    print("************")
    print("iteration", i ," ::::::::;;;;;;;; error::",error)
    print("output:",outputlayer)
# Out:
# ************
# iteration 0  ::::::::;;;;;;;; error:: [[ 0.08920975 -0.91261892]]
# output: [[0.91079025 0.91261892]]
# ************
# iteration 1  ::::::::;;;;;;;; error:: [[ 0.0883152  -0.90290788]]
# output: [[0.9116848  0.90290788]]
# ************
# iteration 2  ::::::::;;;;;;;; error:: [[ 0.08744838 -0.89129384]]
# output: [[0.91255162 0.89129384]]
# ************
# iteration 3  ::::::::;;;;;;;; error:: [[ 0.08660729 -0.87728332]]
# output: [[0.91339271 0.87728332]]
# ************
# iteration 4  ::::::::;;;;;;;; error:: [[ 0.08578969 -0.86024779]]
# output: [[0.91421031 0.86024779]]
# ************
# iteration 5  ::::::::;;;;;;;; error:: [[ 0.08499298 -0.83940543]]
# output: [[0.91500702 0.83940543]]
# ************
# iteration 6  ::::::::;;;;;;;; error:: [[ 0.0842141  -0.81382916]]
# output: [[0.9157859  0.81382916]]
# ************
# iteration 7  ::::::::;;;;;;;; error:: [[ 0.08344945 -0.78251957]]
# output: [[0.91655055 0.78251957]]
# ************
# ...
