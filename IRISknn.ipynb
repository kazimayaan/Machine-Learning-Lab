# %% [markdown]
# <a href="https://colab.research.google.com/github/kazimayaan/Machine-Learning-Lab/blob/main/IRISknn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import csv
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
def KNN(DATA):
  print("enter the sepal length, sepal width, petal length, petal width")
  a,b,c,d = input().split()
  # a = 3.4
  a = float(a)
  # b = 4.3
  b = float(b)
  # c = 6.7
  c = float(c)
  # d = 1.3
  d = float(d)

  for line in DATA:
    x = float(line[0])
    y = float(line[1])
    z = float(line[2])
    w = float(line[3])
    dist= np.sqrt((x-a)**2+(y-b)**2+(z-c)**2+(w-d)**2)
    # print(dist)
    line.append(dist)

    # dist = np.sqrt((x-a)**2+(y-b)**2+(z-c)**2+(w-d)**2)
    # DATA.append(dist)
    # print(x,y ,z,w)
  # for line in DATA:
  #    x = float(line[0])
  #    y = float(line[1])
  #    z = float(line[2])
  #    w = float(line[3])
  #    dist=np.sqrt((x-a)**2+(y-b)**2+(z-c)**2+(w-d)**2)    
  #    DATA.append(dist)
  
  DATA.sort(key= lambda i:i[5])
  # display(DATA)
  print("enter the k value")
  k = input()
  k = int(k)
  

  ser = 0
  vir = 0
  ver = 0
  # print(DATA[0][4])
  for j in range(k):
    if DATA[j][4]=='Iris-setosa':
      ser+=1
    elif DATA[j][4]=='Iris-versicolor':
      ver+=1
    else:
      vir+=1
    # if DATA[j][4]=='Iris Virginica':
    #   print("yaya")
    # print(DATA[j][4])
  # for j in range(k):
  #   if DATA[j][3]=='S':
  #     scount+=1
  #   if DATA[j][3]=='M':
  #     mcount+=1
  #   if DATA[j][3]=='L':
  #     lcount+=1
  #   if DATA[j][3]=='XL':
  #     xlcount+=1

  # for j in range(k):
    # if line[j][4]=='Iris-setosa':
    #   ser+=1
    # elif line[j][4]=='Iris-versicolor':
    #   ver+=1
    # else:
    #   vir+=1
  val=[ser,vir,ver]
  label=['sertosa','virginica','versicolor']
  plt.bar(label,val)
  plt.show()
  if ser>vir and ser>ver:
    print("----------The Flower is Iris Sertosa---------")
  elif vir>ver and vir>ser:
    print("----------The Flower is Iris Virginica---------")
  else:
    print("----------The Flower is Iris Versicolor---------")

# %%
def main():
  file = "/content/iris.csv"
  temp = pd.read_csv(file)
  display(temp)
  fd = csv.reader(open(file))
  data=[]
  for line in fd:
    data.append(line)
  
  DATA= data[1:]

  KNN(DATA)

# %%
main()
# Out:
#      slength  swidth  plength  pwidth        catogary
# 0        5.1     3.5      1.4     0.2     Iris-setosa
# 1        4.9     3.0      1.4     0.2     Iris-setosa
# 2        4.7     3.2      1.3     0.2     Iris-setosa
# 3        4.6     3.1      1.5     0.2     Iris-setosa
# 4        5.0     3.6      1.4     0.2     Iris-setosa
# ..       ...     ...      ...     ...             ...
# 145      6.7     3.0      5.2     2.3  Iris-virginica
# 146      6.3     2.5      5.0     1.9  Iris-virginica
# 147      6.5     3.0      5.2     2.0  Iris-virginica
# 148      6.2     3.4      5.4     2.3  Iris-virginica
# 149      5.9     3.0      5.1     1.8  Iris-virginica
#
# [150 rows x 5 columns]
# enter the sepal length, sepal width, petal length, petal width
# 4.3 4.3 2.3 4.3
# enter the k value
# 5
# ----------The Flower is Iris Versicolor---------
