# %% [markdown]
# <a href="https://colab.research.google.com/github/kazimayaan/Machine-Learning-Lab/blob/main/kmeans.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import csv
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
def kmeans(data):
  print('ente the first centroid')
  w1,h1 = input().split()
  print('ente the sec centroid')
  w2,h2 = input().split()
  print('ente the third centroid')
  w3,h3 = input().split()
  w1 = int(w1)
  h1 = int(h1)
  w2 = int(w2)
  h2 = int(h2)
  w3 = int(w3)
  h3 = int(h3)
  for line in data:
    x = int(line[0])
    y = int(line[1])
    d1 = np.sqrt((x-w1)**2+(y-h1)**2)
    d2 = np.sqrt((x-w2)**2+(y-h2)**2)
    d3 = np.sqrt((x-w3)**2+(y-h3)**2)
    if d1<d2 and d1<d3:
      print("the wight",x,"and height",y,"belongs to cluster 1/lightweight")
      w1 = (w1+x)/2
      h1 = (h1+y)/2
      plt.scatter(x,y,c='red')
    elif d2<d3 and d2<d1:
      print("the wight",x,"and height",y,"belongs to cluster 2/middleweight")
      w2 = (w2+x)/2
      h2 = (h2+y)/2
      plt.scatter(x,y,c='blue')
    else:
      print("the wight",x,"and height",y,"belongs to cluster 3/heavyweight")
      w3 = (w3+x)/2
      h3 = (h3+y)/2
      plt.scatter(x,y,c='green')
  plt.show()

# %%
def main():
  file = "/content/BOXING.csv"
  temp = pd.read_csv(file)
  display(temp)
  data=[]
  fd= csv.reader(open(file))
  for line in fd:
    data.append(line)
  DATA=data[1:]
  kmeans(DATA)

# %%
main()
# Out:
#     weight  height
# 0       90     185
# 1       50     165
# 2       95     175
# 3       85     173
# 4       65     169
# 5       55     170
# 6       68     160
# 7       49     163
# 8       86     170
# 9      100     167
# 10      99     175
# 11      74     170
# 12      68     167
# 13      55     170
# 14      48     160
# 15      95     170
# 16     100     177
# 17      67     170
# 18      80     178
# 19      77     173
# ente the first centroid
# 50 150
# ente the sec centroid
# 70 170
# ente the third centroid
# 100 200
# the wight 90 and height 185 belongs to cluster 3/heavyweight
# the wight 50 and height 165 belongs to cluster 1/lightweight
# the wight 95 and height 175 belongs to cluster 3/heavyweight
# the wight 85 and height 173 belongs to cluster 3/heavyweight
# the wight 65 and height 169 belongs to cluster 2/middleweight
# the wight 55 and height 170 belongs to cluster 2/middleweight
# the wight 68 and height 160 belongs to cluster 2/middleweight
# the wight 49 and height 163 belongs to cluster 1/lightweight
# the wight 86 and height 170 belongs to cluster 3/heavyweight
# the wight 100 and height 167 belongs to cluster 3/heavyweight
# the wight 99 and height 175 belongs to cluster 3/heavyweight
# the wight 74 and height 170 belongs to cluster 2/middleweight
# the wight 68 and height 167 belongs to cluster 2/middleweight
# the wight 55 and height 170 belongs to cluster 1/lightweight
# the wight 48 and height 160 belongs to cluster 1/lightweight
# the wight 95 and height 170 belongs to cluster 3/heavyweight
# the wight 100 and height 177 belongs to cluster 3/heavyweight
# the wight 67 and height 170 belongs to cluster 2/middleweight
# the wight 80 and height 178 belongs to cluster 2/middleweight
# the wight 77 and height 173 belongs to cluster 2/middleweight
