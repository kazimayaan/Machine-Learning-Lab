# %% [markdown]
# <a href="https://colab.research.google.com/github/kazimayaan/Machine-Learning-Lab/blob/main/bpppractise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
ipn = 2
opn = 2
hln = 2

input = np.random.randint(1,5,ipn)
output = np.array([1.0,0.0])
hiddenlayer = np.random.rand(1,hln)

hidden_bias = np.random.rand(1,hln)
output_bias = np.random.rand(1,opn)

hidden_weight = np.random.rand(ipn,hln)
output_weight = np.random.rand(hln,opn)

def sigmoid(layer):
  return 1/ (1+np.exp(-layer))
def gradient(layer):
  return layer*(1-layer)

for i in range(6000):

  hiddenlayer = np.dot(input, hidden_weight)
  hiddenlayer= sigmoid(hiddenlayer+ hidden_bias)

  outputlayer = np.dot(hiddenlayer,output_weight)
  outputlayer = sigmoid(outputlayer+output_bias)

  error = output- outputlayer

  errortop = gradient(outputlayer)*error
  errorthl = gradient(hiddenlayer)*np.dot(errortop, output_weight.T)

  gradhl = np.dot(input.reshape(ipn,1),errorthl.reshape(1,hln))
  gradop = np.dot(hiddenlayer.reshape(hln,1),errortop.reshape(1,opn))

  hidden_weight = hidden_weight + 0.5*gradhl
  output_weight = output_weight + 0.5*gradop

  print("********")
  print("iteration", i , "error: ",error)
  print("####output###", outputlayer)
  print()
# Out:
# Streaming output truncated to the last 5000 lines.
# ********
# iteration 4750 error:  [[ 0.01048802 -0.01050385]]
# ####output### [[0.98951198 0.01050385]]
#
# ********
# iteration 4751 error:  [[ 0.0104869  -0.01050272]]
# ####output### [[0.9895131  0.01050272]]
#
# ********
# iteration 4752 error:  [[ 0.01048577 -0.01050159]]
# ####output### [[0.98951423 0.01050159]]
#
# ********
# iteration 4753 error:  [[ 0.01048464 -0.01050046]]
# ####output### [[0.98951536 0.01050046]]
#
# ********
# iteration 4754 error:  [[ 0.01048352 -0.01049933]]
# ####output### [[0.98951648 0.01049933]]
#
# ********
# iteration 4755 error:  [[ 0.0104824 -0.0104982]]
# ####output### [[0.9895176 0.0104982]]
#
# ********
# iteration 4756 error:  [[ 0.01048127 -0.01049707]]
# ####output### [[0.98951873 0.01049707]]
#
# ********
# iteration 4757 error:  [[ 0.01048015 -0.01049594]]
# ####output### [[0.98951985 0.01049594]]
#
# ********
# iteration 4758 error:  [[ 0.01047902 -0.01049481]]
# ...
